# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy
import pandas as pd
import IPython.display as ipd
import librosa
import librosa.display

# %%
metadata = pd.read_csv("data/data/metadata/data.csv")
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
# %matplotlib inline

# %%
filename=  "dog_bark.mp3"

# %%
plt.figure(figsize=(14, 5))

# %%
#dog sound
data, sample_rate = librosa.load(filename)
librosa.display.waveshow(data, sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data
# Out:
# array([-5.4083998e-10,  7.1868422e-10,  1.0364460e-09, ...,
#         4.4364899e-07,  9.6244162e-07,  1.0571916e-06],
#       shape=(22756,), dtype=float32)

# %%
metadata
# Out:
#          slice_file_name    fsID       start         end  salience  fold  \
# 0       100032-3-0-0.wav  100032    0.000000    0.317551         1     5
# 1     100263-2-0-117.wav  100263   58.500000   62.500000         1     5
# 2     100263-2-0-121.wav  100263   60.500000   64.500000         1     5
# 3     100263-2-0-126.wav  100263   63.000000   67.000000         1     5
# 4     100263-2-0-137.wav  100263   68.500000   72.500000         1     5
# ...                  ...     ...         ...         ...       ...   ...
# 8727     99812-1-2-0.wav   99812  159.522205  163.522205         2     7
# 8728     99812-1-3-0.wav   99812  181.142431  183.284976         2     7
# 8729     99812-1-4-0.wav   99812  242.691902  246.197885         2     7
# 8730     99812-1-5-0.wav   99812  253.209850  255.741948         2     7
# 8731     99812-1-6-0.wav   99812  332.289233  334.821332         2     7
#
#       classID             class
# 0           3          dog_bark
# ...

# %%
len(data)
# Out:
# 22756

# %%
audio_flie_path = "data/data/audio/fold9/7063-6-0-0.wav"

# %%
data, sample_rate = librosa.load(audio_flie_path)
librosa.display.waveshow(data, sr=sample_rate)
ipd.Audio(audio_flie_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from scipy.io import wavfile as wav
wav_sample_rate, wav_audio = wav.read(audio_flie_path)

# %%
wav_audio
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 0],
#        ...,
#        [3, 5],
#        [0, 3],
#        [1, 3]], shape=(77879, 2), dtype=int16)

# %%
plt.figure(figsize=(12, 10))
plt.plot(wav_audio)

# %%
mfccs = librosa.feature.mfcc(y = data, sr = sample_rate, n_mfcc=40)
print(mfccs.shape)
# Out:
# (40, 77)

# %%
mfccs
# Out:
# array([[-1.8912953e+02, -1.2050093e+01,  2.3500689e+01, ...,
#         -5.3002014e+02, -5.3441071e+02, -5.3669434e+02],
#        [ 3.8301483e+01,  1.9194794e+01,  1.1266786e+01, ...,
#          1.3662697e+01,  7.4797211e+00,  4.2570524e+00],
#        [ 1.9845047e+01,  2.1892918e+01,  2.1407486e+01, ...,
#          1.3555893e+01,  7.4512124e+00,  4.2492094e+00],
#        ...,
#        [-3.1705925e+00, -9.7909606e-01,  2.1356549e+00, ...,
#         -1.1095002e+00,  7.6237464e-01,  1.5854342e+00],
#        [ 5.8942425e-01,  7.7185249e-01,  1.3692102e+00, ...,
#         -1.0855544e+00,  6.2700039e-01,  1.4835186e+00],
#        [ 5.8905807e+00,  8.3009396e+00,  6.6032333e+00, ...,
#         -1.0418341e+00,  5.0220293e-01,  1.3828932e+00]],
#       shape=(40, 77), dtype=float32)
